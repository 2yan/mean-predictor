# %%
import keras as kr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
from datetime import datetime
import seaborn as sea

# %%
files = glob('data/*.csv')
files
# Out:
# ['data\\gemini_ETHUSD_2016_1min.csv', 'data\\gemini_ETHUSD_2018_1min.csv']

# %%
def get_data(filenumber = 1):
    data = pd.read_csv(files[filenumber])
    data.columns = data.columns.str.lower()
    data['date'] = data['unix timestamp'].map(lambda x: datetime.fromtimestamp(x/1000))
    data.sort_values('date', inplace = True)
    data.reset_index(inplace = True, drop = True)
    return data

# %%
data = get_data()

center = True
data['avg'] = data.rolling(20, center = center)['close'].mean()
data['avg_x'] = data.rolling(20)['close'].mean()
#start = np.random.randint(0, len(data) - 5000)
data['next'] = data['close'].shift(-1)
data = data.dropna()


fig, ax = plt.subplots()
fig.set_size_inches(10 * 1.5, 9 )
x = data.iloc[start:start + 300]
x[['close', 'avg', 'avg_x']].plot(ax = ax)
sea.despine(ax = ax)

# %%
start = x.index.min()


data['close'] = data['close'].pct_change()
mask = data['volume'] == 0
data.loc[mask, 'volume'] = 0.01
data['volume'] = data['volume'].pct_change()
mask = data['volume'] == 0
data.loc[mask, 'volume'] = 0.1
data['volume'] = np.log(data['volume'])
data = data.dropna()
# Out:
# C:\Users\rfrancis\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in log
#   # Remove the CWD from sys.path while we load stuff.

# %%
timesteps = 25
X = []
y = []

for i in range(len(data)-  timesteps):
    X.append(data.iloc[i:i + timesteps][['close', 'volume']].values)
    actual = data.iloc[i + timesteps]['avg']
    lagged = data.iloc[i + timesteps]['avg_x']
    y.append((actual - lagged)/lagged)
    
    
X = np.array(X)
y = np.array(y)

# %%
sea.distplot(y, kde = False)
# Out:
# C:\Users\rfrancis\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
def generate_model(X, y):
    model = kr.models.Sequential()
    model.add(kr.layers.LSTM(32, input_shape=X.shape[1:]))
    model.add(kr.layers.Dense(16))
    model.add(kr.layers.Dense(1))
    optimizer = kr.optimizers.RMSprop(lr=0.01)
    model.compile(loss='mean_absolute_error', optimizer=optimizer)
    return model

#model = generate_model(X,y)
model.fit(X, y,batch_size=7000,epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 147000/271483 [===============>..............] - ETA: 9s - loss: 0.0060

# %%
def predict(data):
    timesteps = 25


    ans = pd.Series(index = data.index)
    
    for i in range(timesteps, len(data)):
        x = data.iloc[i - timesteps: i][['close', 'volume']].values
        y = model.predict(np.array([x]))
        ans.iloc[i] = y
        
    return ans

# %%
start = np.random.randint(len(data))

# %%
x = data.loc[start: start + 300]
x['pred_avg'] = predict(x)
x = x.dropna()
x['pred_avg'] = x['avg_x'] +   (x['pred_avg'] * x['avg_x'])

differences = x['avg_x'] - x['avg']
min_pos = differences.apply(abs).idxmin()
#shift = x.loc[min_pos, 'pred_avg'] - x.loc[min_pos, 'avg_x']
#x['pred_avg'] = x['pred_avg'] - shift

fig, ax = plt.subplots()
fig.set_size_inches(8  * 2 , 8)
x[['avg', 'avg_x', 'pred_avg']].plot(ax = ax)
# Out:
# C:\Users\rfrancis\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
